# %% [markdown]
# ## WeatherPy

# %% [markdown]
# **Note**
#
# - Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from JamesWilliams_api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
#
# - Perform a weather check on each city using a series of successive API calls.
# - Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call

# List of city data

# Print to logger

print(f'\nBeginning Data Retrieval\n\
-----------------------------\n')

record = 0
sets = 1
cities_weather = []

for city in cities:
    
    record += 1
    print(f'Processing Record {record} of Set {sets} | {city}')
    
    if(record == 50):
        record = 0
        sets += 1
    
    url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&q={city}&APPID={weather_api_key}" 
    time.sleep(1)
    response = requests.get(url).json()
    
    try:
        cities_weather.append({
            'City': city,
            'Lat': response['coord']['lat'],
            'Lon': response['coord']['lon'],
            'Max Temp': response['main']['temp_max'],
            'Humidity': response['main']['humidity'],
            'Cloudiness': response['clouds']['all'],
            'Wind Speed': response['wind']['speed'],
            'Country': response['sys']['country'],
            'Date': response['dt'],
            })
    except:
        print('City not found. Skipping...')
print('-----------------------------\nData Retrieval Complete\n-----------------------------')
    
# Create counters

# Loop through all the cities in our list

    # Group cities in sets of 50 for logging purposes

    # Create endpoint URL with each city
    
    # Log the url, record, and set numbers

    # Add 1 to the record count

    # Run an API request for each of the cities
    
        # Parse the JSON and retrieve data

        # Parse out the max temp, humidity, and cloudiness

        # Append the City information into city_data list

    # If an error is experienced, skip the city
              
# Indicate that Data Loading is complete
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | tungor
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | nanortalik
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | nantucket
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | lodja
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | biskamzha
# Processing Record 12 of Set 1 | la rioja
# Processing Record 13 of Set 1 | ocampo
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | matara
# Processing Record 16 of Set 1 | taltal
# Processing Record 17 of Set 1 | klaksvik
# Processing Record 18 of Set 1 | padang
# Processing Record 19 of Set 1 | manzhouli
# Processing Record 20 of Set 1 | hofn
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | te anau
# Processing Record 23 of Set 1 | aktash
# Processing Record 24 of Set 1 | saint-joseph
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 1 | leh
# Processing Record 30 of Set 1 | caucaia
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | lekoni
# Processing Record 33 of Set 1 | luba
# Processing Record 34 of Set 1 | coihaique
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | juneau
# Processing Record 39 of Set 1 | coahuayana
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | kinsale
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | saint-georges
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | cotonou
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | bandarbeyla
# Processing Record 1 of Set 2 | namatanai
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | narsaq
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | lorengau
# Processing Record 6 of Set 2 | danielskuil
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | haines junction
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 2 | vardo
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | boffa
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | japura
# Processing Record 20 of Set 2 | buchanan
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | puerto palomas
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | vicuna
# Processing Record 26 of Set 2 | ambilobe
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | tolaga bay
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | eyl
# Processing Record 34 of Set 2 | flinders
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | ahipara
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | verkhnevilyuysk
# Processing Record 40 of Set 2 | vreed en hoop
# City not found. Skipping...
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | belaya gora
# Processing Record 45 of Set 2 | tuatapere
# Processing Record 46 of Set 2 | urfa
# City not found. Skipping...
# Processing Record 47 of Set 2 | saryg-sep
# Processing Record 48 of Set 2 | amahai
# Processing Record 49 of Set 2 | husavik
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | fortuna
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | marawi
# Processing Record 5 of Set 3 | rurrenabaque
# Processing Record 6 of Set 3 | samarai
# Processing Record 7 of Set 3 | kamina
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | ritchie
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | dubbo
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | wukari
# Processing Record 16 of Set 3 | pevek
# Processing Record 17 of Set 3 | clyde
# Processing Record 18 of Set 3 | nioro
# Processing Record 19 of Set 3 | hualmay
# Processing Record 20 of Set 3 | hella
# Processing Record 21 of Set 3 | rikitea
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | itarema
# Processing Record 24 of Set 3 | kloulklubed
# Processing Record 25 of Set 3 | pucara
# Processing Record 26 of Set 3 | turner
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | milagro
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | moose factory
# Processing Record 33 of Set 3 | bridlington
# Processing Record 34 of Set 3 | angoram
# Processing Record 35 of Set 3 | shelburne
# Processing Record 36 of Set 3 | batagay-alyta
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | shahpur
# Processing Record 40 of Set 3 | berlevag
# Processing Record 41 of Set 3 | karmana
# City not found. Skipping...
# Processing Record 42 of Set 3 | angouleme
# Processing Record 43 of Set 3 | galle
# Processing Record 44 of Set 3 | barahona
# Processing Record 45 of Set 3 | lalmohan
# Processing Record 46 of Set 3 | igarka
# Processing Record 47 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | nikolayevsk-na-amure
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | cimahi
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | yelizovo
# Processing Record 4 of Set 4 | wana
# Processing Record 5 of Set 4 | shaunavon
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | villazon
# Processing Record 9 of Set 4 | ust-kut
# Processing Record 10 of Set 4 | bar-le-duc
# Processing Record 11 of Set 4 | muncar
# Processing Record 12 of Set 4 | lima
# Processing Record 13 of Set 4 | karratha
# Processing Record 14 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 4 | yacopi
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | bandipur
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | smithers
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | abashiri
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | manokwari
# Processing Record 29 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | kenai
# Processing Record 31 of Set 4 | sulangan
# Processing Record 32 of Set 4 | alexandria
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | gazanjyk
# Processing Record 35 of Set 4 | chegdomyn
# Processing Record 36 of Set 4 | ketchikan
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | bredasdorp
# Processing Record 39 of Set 4 | mogapi
# Processing Record 40 of Set 4 | terney
# Processing Record 41 of Set 4 | zambezi
# Processing Record 42 of Set 4 | touros
# Processing Record 43 of Set 4 | champerico
# Processing Record 44 of Set 4 | tefe
# Processing Record 45 of Set 4 | tura
# Processing Record 46 of Set 4 | katha
# City not found. Skipping...
# Processing Record 47 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | tacuarembo
# Processing Record 1 of Set 5 | peniche
# Processing Record 2 of Set 5 | tiznit
# Processing Record 3 of Set 5 | xinye
# Processing Record 4 of Set 5 | margate
# Processing Record 5 of Set 5 | tessalit
# Processing Record 6 of Set 5 | kuytun
# Processing Record 7 of Set 5 | port victoria
# Processing Record 8 of Set 5 | hammerfest
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | omaruru
# Processing Record 11 of Set 5 | shinpokh
# Processing Record 12 of Set 5 | evensk
# Processing Record 13 of Set 5 | krasnoarmeysk
# Processing Record 14 of Set 5 | dingle
# Processing Record 15 of Set 5 | monywa
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | arvika
# Processing Record 18 of Set 5 | vestmannaeyjar
# Processing Record 19 of Set 5 | lakewood
# Processing Record 20 of Set 5 | makaryev
# Processing Record 21 of Set 5 | vila velha
# Processing Record 22 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 23 of Set 5 | tazovskiy
# Processing Record 24 of Set 5 | seoul
# Processing Record 25 of Set 5 | seydi
# Processing Record 26 of Set 5 | marshall
# Processing Record 27 of Set 5 | tucumcari
# Processing Record 28 of Set 5 | manzanillo
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | kambove
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | broome
# Processing Record 33 of Set 5 | castro
# Processing Record 34 of Set 5 | dubovskoye
# Processing Record 35 of Set 5 | whitehorse
# Processing Record 36 of Set 5 | constitucion
# Processing Record 37 of Set 5 | zabol
# Processing Record 38 of Set 5 | axim
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | burshtyn
# Processing Record 41 of Set 5 | yinchuan
# Processing Record 42 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 5 | chumikan
# Processing Record 44 of Set 5 | puerto narino
# Processing Record 45 of Set 5 | albuquerque
# Processing Record 46 of Set 5 | tutoia
# Processing Record 47 of Set 5 | guadalajara
# Processing Record 48 of Set 5 | portland
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | bambanglipuro
# Processing Record 1 of Set 6 | basco
# Processing Record 2 of Set 6 | poum
# Processing Record 3 of Set 6 | yasnyy
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | inirida
# Processing Record 6 of Set 6 | phalaborwa
# Processing Record 7 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | kahului
# Processing Record 10 of Set 6 | vaini
# Processing Record 11 of Set 6 | ajdabiya
# Processing Record 12 of Set 6 | rio do sul
# Processing Record 13 of Set 6 | kranuan
# Processing Record 14 of Set 6 | zarakes
# City not found. Skipping...
# Processing Record 15 of Set 6 | nouadhibou
# Processing Record 16 of Set 6 | brest
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | kinkala
# Processing Record 19 of Set 6 | kapit
# Processing Record 20 of Set 6 | roald
# Processing Record 21 of Set 6 | boralday
# Processing Record 22 of Set 6 | rio cuarto
# Processing Record 23 of Set 6 | kotido
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | geraldton
# Processing Record 26 of Set 6 | korla
# Processing Record 27 of Set 6 | kamloops
# Processing Record 28 of Set 6 | kumbo
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | ruwi
# Processing Record 31 of Set 6 | bulaevo
# Processing Record 32 of Set 6 | shetpe
# Processing Record 33 of Set 6 | yumen
# Processing Record 34 of Set 6 | riyadh
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | walvis bay
# Processing Record 37 of Set 6 | tadine
# Processing Record 38 of Set 6 | aparecida do taboado
# Processing Record 39 of Set 6 | apud
# Processing Record 40 of Set 6 | vestmanna
# Processing Record 41 of Set 6 | naberera
# Processing Record 42 of Set 6 | sao joao da barra
# Processing Record 43 of Set 6 | orange
# Processing Record 44 of Set 6 | russell
# Processing Record 45 of Set 6 | mitsamiouli
# Processing Record 46 of Set 6 | nanakuli
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | misratah
# Processing Record 49 of Set 6 | feijo
# Processing Record 50 of Set 6 | waingapu
# Processing Record 1 of Set 7 | kalispell
# Processing Record 2 of Set 7 | lagoa
# Processing Record 3 of Set 7 | wielun
# Processing Record 4 of Set 7 | vaasa
# Processing Record 5 of Set 7 | yar-sale
# Processing Record 6 of Set 7 | venustiano carranza
# Processing Record 7 of Set 7 | mehamn
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | kajaani
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | georgetown
# Processing Record 12 of Set 7 | jishou
# Processing Record 13 of Set 7 | dali
# Processing Record 14 of Set 7 | nigel
# Processing Record 15 of Set 7 | roma
# Processing Record 16 of Set 7 | harwich
# Processing Record 17 of Set 7 | tiksi
# Processing Record 18 of Set 7 | olafsvik
# Processing Record 19 of Set 7 | maltahohe
# Processing Record 20 of Set 7 | mar del plata
# Processing Record 21 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 7 | bollnas
# Processing Record 23 of Set 7 | poya
# Processing Record 24 of Set 7 | gopalpur
# Processing Record 25 of Set 7 | kudahuvadhoo
# Processing Record 26 of Set 7 | licheng
# Processing Record 27 of Set 7 | fairbanks
# Processing Record 28 of Set 7 | nome
# Processing Record 29 of Set 7 | baruun-urt
# Processing Record 30 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 7 | provideniya
# Processing Record 33 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 7 | torbay
# Processing Record 35 of Set 7 | kilindoni
# Processing Record 36 of Set 7 | taoudenni
# Processing Record 37 of Set 7 | union
# Processing Record 38 of Set 7 | hwange
# Processing Record 39 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 7 | gambela
# Processing Record 41 of Set 7 | palana
# Processing Record 42 of Set 7 | narrabri
# Processing Record 43 of Set 7 | baykit
# Processing Record 44 of Set 7 | tabou
# Processing Record 45 of Set 7 | henties bay
# Processing Record 46 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 7 | na wa
# Processing Record 48 of Set 7 | leningradskiy
# Processing Record 49 of Set 7 | stornoway
# Processing Record 50 of Set 7 | turukhansk
# Processing Record 1 of Set 8 | paldiski
# Processing Record 2 of Set 8 | tsevie
# Processing Record 3 of Set 8 | mapastepec
# Processing Record 4 of Set 8 | santa clara
# Processing Record 5 of Set 8 | nelson bay
# Processing Record 6 of Set 8 | kampenhout
# Processing Record 7 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 8 | kwakoa
# Processing Record 9 of Set 8 | conil
# Processing Record 10 of Set 8 | ust-kuyga
# Processing Record 11 of Set 8 | avera
# Processing Record 12 of Set 8 | tucuman
# Processing Record 13 of Set 8 | hambantota
# Processing Record 14 of Set 8 | novobirilyussy
# Processing Record 15 of Set 8 | tual
# Processing Record 16 of Set 8 | kieta
# Processing Record 17 of Set 8 | yulara
# Processing Record 18 of Set 8 | dukat
# Processing Record 19 of Set 8 | kingman
# Processing Record 20 of Set 8 | lazaro cardenas
# Processing Record 21 of Set 8 | talara
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | yangjiang
# Processing Record 24 of Set 8 | santa isabel do rio negro
# Processing Record 25 of Set 8 | bogorodskoye
# Processing Record 26 of Set 8 | pompeia
# Processing Record 27 of Set 8 | diamantino
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 30 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 8 | changtu
# Processing Record 32 of Set 8 | anadyr
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 8 | klyuchi
# Processing Record 36 of Set 8 | behshahr
# Processing Record 37 of Set 8 | adrar
# Processing Record 38 of Set 8 | pokrovsk
# Processing Record 39 of Set 8 | aklavik
# Processing Record 40 of Set 8 | ilulissat
# Processing Record 41 of Set 8 | maxixe
# Processing Record 42 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 43 of Set 8 | bac lieu
# Processing Record 44 of Set 8 | zaltan
# Processing Record 45 of Set 8 | huarmey
# Processing Record 46 of Set 8 | banda aceh
# Processing Record 47 of Set 8 | trinidad
# Processing Record 48 of Set 8 | sisimiut
# Processing Record 49 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 8 | miracema do tocantins
# Processing Record 1 of Set 9 | katsuura
# Processing Record 2 of Set 9 | yerbogachen
# Processing Record 3 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 9 | abalak
# Processing Record 5 of Set 9 | senno
# Processing Record 6 of Set 9 | yurgamysh
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | vanimo
# Processing Record 9 of Set 9 | jalingo
# Processing Record 10 of Set 9 | ulaanbaatar
# Processing Record 11 of Set 9 | dajabon
# Processing Record 12 of Set 9 | phan thiet
# Processing Record 13 of Set 9 | hostotipaquillo
# Processing Record 14 of Set 9 | agirish
# Processing Record 15 of Set 9 | mahajanga
# Processing Record 16 of Set 9 | taylorville
# Processing Record 17 of Set 9 | nikolskoye
# Processing Record 18 of Set 9 | kilrush
# Processing Record 19 of Set 9 | moree
# Processing Record 20 of Set 9 | sioux lookout
# Processing Record 21 of Set 9 | abengourou
# Processing Record 22 of Set 9 | hamois
# Processing Record 23 of Set 9 | phuket
# Processing Record 24 of Set 9 | sur
# Processing Record 25 of Set 9 | swift current
# Processing Record 26 of Set 9 | senneterre
# Processing Record 27 of Set 9 | antalaha
# Processing Record 28 of Set 9 | karpathos
# Processing Record 29 of Set 9 | deputatskiy
# Processing Record 30 of Set 9 | mizque
# Processing Record 31 of Set 9 | sobolivka
# Processing Record 32 of Set 9 | zhob
# Processing Record 33 of Set 9 | hamilton
# Processing Record 34 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 9 | bella union
# Processing Record 36 of Set 9 | portobelo
# Processing Record 37 of Set 9 | tukrah
# Processing Record 38 of Set 9 | coquimbo
# Processing Record 39 of Set 9 | tilichiki
# Processing Record 40 of Set 9 | murray bridge
# Processing Record 41 of Set 9 | labuhan
# Processing Record 42 of Set 9 | quelimane
# Processing Record 43 of Set 9 | kendari
# Processing Record 44 of Set 9 | maarianhamina
# Processing Record 45 of Set 9 | didi lilo
# Processing Record 46 of Set 9 | iwanai
# Processing Record 47 of Set 9 | ranong
# Processing Record 48 of Set 9 | khartoum
# Processing Record 49 of Set 9 | ribeira brava
# Processing Record 50 of Set 9 | kingston
# Processing Record 1 of Set 10 | ngaoundere
# Processing Record 2 of Set 10 | egvekinot
# Processing Record 3 of Set 10 | handwara
# City not found. Skipping...
# Processing Record 4 of Set 10 | paita
# Processing Record 5 of Set 10 | santa maria
# Processing Record 6 of Set 10 | sungaipenuh
# Processing Record 7 of Set 10 | annau
# Processing Record 8 of Set 10 | rio grande
# Processing Record 9 of Set 10 | rawson
# Processing Record 10 of Set 10 | mercedes
# Processing Record 11 of Set 10 | cockburn town
# Processing Record 12 of Set 10 | panjab
# Processing Record 13 of Set 10 | dauphin
# Processing Record 14 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 10 | grand baie
# Processing Record 19 of Set 10 | pisco
# Processing Record 20 of Set 10 | kualakapuas
# Processing Record 21 of Set 10 | laguna
# Processing Record 22 of Set 10 | quepos
# Processing Record 23 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 10 | bilma
# Processing Record 25 of Set 10 | altamira
# Processing Record 26 of Set 10 | usinsk
# Processing Record 27 of Set 10 | banyuwangi
# Processing Record 28 of Set 10 | zhigansk
# Processing Record 29 of Set 10 | komsomolskiy
# Processing Record 30 of Set 10 | davila
# Processing Record 31 of Set 10 | pavlovka
# Processing Record 32 of Set 10 | esil
# Processing Record 33 of Set 10 | lasa
# Processing Record 34 of Set 10 | lashio
# Processing Record 35 of Set 10 | kavieng
# Processing Record 36 of Set 10 | comodoro rivadavia
# Processing Record 37 of Set 10 | ariquemes
# Processing Record 38 of Set 10 | san quintin
# Processing Record 39 of Set 10 | san juan de los lagos
# Processing Record 40 of Set 10 | shingu
# Processing Record 41 of Set 10 | paz de ariporo
# City not found. Skipping...
# Processing Record 42 of Set 10 | mandera
# Processing Record 43 of Set 10 | lavos
# Processing Record 44 of Set 10 | surok
# Processing Record 45 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 46 of Set 10 | saint anthony
# Processing Record 47 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 10 | makakilo city
# Processing Record 49 of Set 10 | boddam
# Processing Record 50 of Set 10 | takoradi
# Processing Record 1 of Set 11 | katobu
# Processing Record 2 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 3 of Set 11 | ibotirama
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | kota belud
# Processing Record 6 of Set 11 | kaoma
# Processing Record 7 of Set 11 | belogradcik
# City not found. Skipping...
# Processing Record 8 of Set 11 | fomboni
# Processing Record 9 of Set 11 | placido de castro
# Processing Record 10 of Set 11 | college
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | dzhebariki-khaya
# Processing Record 13 of Set 11 | changzhou
# Processing Record 14 of Set 11 | monte alegre
# Processing Record 15 of Set 11 | kearney
# Processing Record 16 of Set 11 | ponta delgada
# Processing Record 17 of Set 11 | yeppoon
# Processing Record 18 of Set 11 | goderich
# Processing Record 19 of Set 11 | oktyabrskoye
# Processing Record 20 of Set 11 | merauke
# Processing Record 21 of Set 11 | chifeng
# Processing Record 22 of Set 11 | kuching
# Processing Record 23 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 24 of Set 11 | kantunilkin
# Processing Record 25 of Set 11 | srednekolymsk
# Processing Record 26 of Set 11 | pierre
# Processing Record 27 of Set 11 | tsentralnyy
# City not found. Skipping...
# Processing Record 28 of Set 11 | innisfail
# Processing Record 29 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 11 | pinheiro machado
# Processing Record 31 of Set 11 | nalut
# Processing Record 32 of Set 11 | borovskoy
# Processing Record 33 of Set 11 | orshanka
# Processing Record 34 of Set 11 | qandala
# Processing Record 35 of Set 11 | mirador
# Processing Record 36 of Set 11 | paamiut
# Processing Record 37 of Set 11 | cayenne
# Processing Record 38 of Set 11 | kiama
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | sorong
# Processing Record 41 of Set 11 | rongai
# Processing Record 42 of Set 11 | tessaoua
# Processing Record 43 of Set 11 | moosomin
# Processing Record 44 of Set 11 | solnechnyy
# Processing Record 45 of Set 11 | siocon
# Processing Record 46 of Set 11 | vao
# Processing Record 47 of Set 11 | piacabucu
# Processing Record 48 of Set 11 | vega de alatorre
# Processing Record 49 of Set 11 | faya
# Processing Record 50 of Set 11 | meulaboh
# Processing Record 1 of Set 12 | a
# City not found. Skipping...
# Processing Record 2 of Set 12 | emerald
# Processing Record 3 of Set 12 | saint-ambroise
# Processing Record 4 of Set 12 | hebi
# Processing Record 5 of Set 12 | idrinskoye
# Processing Record 6 of Set 12 | coruripe
# Processing Record 7 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 12 | san vicente
# Processing Record 9 of Set 12 | redlands
# Processing Record 10 of Set 12 | selma
# Processing Record 11 of Set 12 | champaign
# Processing Record 12 of Set 12 | mount isa
# Processing Record 13 of Set 12 | santa lucia
# Processing Record 14 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 15 of Set 12 | srivardhan
# Processing Record 16 of Set 12 | bayir
# Processing Record 17 of Set 12 | lufilufi
# Processing Record 18 of Set 12 | muroto
# Processing Record 19 of Set 12 | san ignacio
# Processing Record 20 of Set 12 | grand gaube
# Processing Record 21 of Set 12 | ambon
# Processing Record 22 of Set 12 | ljubimec
# City not found. Skipping...
# Processing Record 23 of Set 12 | havre-saint-pierre
# Processing Record 24 of Set 12 | yatou
# Processing Record 25 of Set 12 | tiarei
# Processing Record 26 of Set 12 | mugan
# Processing Record 27 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 28 of Set 12 | grindavik
# Processing Record 29 of Set 12 | jaicos
# Processing Record 30 of Set 12 | kalemie
# Processing Record 31 of Set 12 | almaznyy
# Processing Record 32 of Set 12 | ramhormoz
# Processing Record 33 of Set 12 | kapoeta
# Processing Record 34 of Set 12 | norfolk
# Processing Record 35 of Set 12 | andenes
# Processing Record 36 of Set 12 | aguas vermelhas
# Processing Record 37 of Set 12 | zhaotong
# Processing Record 38 of Set 12 | okhotsk
# Processing Record 39 of Set 12 | bowling green
# Processing Record 40 of Set 12 | rio gallegos
# Processing Record 41 of Set 12 | ostersund
# Processing Record 42 of Set 12 | jacareacanga
# Processing Record 43 of Set 12 | turiacu
# Processing Record 44 of Set 12 | dzaoudzi
# Processing Record 45 of Set 12 | korhogo
# Processing Record 46 of Set 12 | thanh hoa
# Processing Record 47 of Set 12 | rocha
# Processing Record 48 of Set 12 | kikwit
# Processing Record 49 of Set 12 | kitui
# Processing Record 50 of Set 12 | yokadouma
# Processing Record 1 of Set 13 | roebourne
# Processing Record 2 of Set 13 | samfya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# - Export the city data into a .csv.
# - Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
cities_weather_df = pd.DataFrame(cities_weather)
# Show Record Count
cities_weather_df.count()
# Out:
# City          545
# Lat           545
# Lon           545
# Max Temp      545
# Humidity      545
# Cloudiness    545
# Wind Speed    545
# Country       545
# Date          545
# dtype: int64

# %%
# Display the City Data Frame
cities_weather_df
# Out:
#             City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         tungor  53.38  142.96     34.14        91          89        3.29
# 1           hilo  19.73 -155.09     73.40        88          40        3.36
# 2           lebu -37.62  -73.65     54.25        64          19       12.53
# 3     nanortalik  60.14  -45.24     31.01        89         100        3.96
# 4    port alfred -33.59   26.89     69.66        88          68        2.68
# ..           ...    ...     ...       ...       ...         ...         ...
# 540       kikwit  -5.04   18.82     74.75        90          87        2.17
# 541        kitui  -1.37   38.01     69.42        74          50        9.33
# 542    yokadouma   3.52   15.05     71.35        95          99        1.45
# 543    roebourne -20.78  117.13     66.74        91          32        3.09
# 544       samfya -11.36   29.56     80.02        37          65        3.96
#
#     Country        Date
# 0        RU  1603821583
# 1        US  1603821558
# 2        CL  1603821586
# 3        GL  1603821587
# 4        ZA  1603821588
# ..      ...         ...
# 540      CD  1603822280
# 541      KE  1603822281
# 542      CM  1603822282
# 543      AU  1603822284
# 544      ZM  1603822285
#
# [545 rows x 9 columns]

# %% [markdown]
# ### Inspect the data and remove the cities where the humidity > 100%.
#
# - Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_outliers = cities_weather_df.loc[cities_weather_df['Humidity'] > 100]
humidity_outliers
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lon, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indices = cities_weather_df.index[cities_weather_df['Humidity']>100].tolist()
indices
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = cities_weather_df.drop(indices, inplace=False)
clean_city_data
# Out:
#             City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         tungor  53.38  142.96     34.14        91          89        3.29
# 1           hilo  19.73 -155.09     73.40        88          40        3.36
# 2           lebu -37.62  -73.65     54.25        64          19       12.53
# 3     nanortalik  60.14  -45.24     31.01        89         100        3.96
# 4    port alfred -33.59   26.89     69.66        88          68        2.68
# ..           ...    ...     ...       ...       ...         ...         ...
# 540       kikwit  -5.04   18.82     74.75        90          87        2.17
# 541        kitui  -1.37   38.01     69.42        74          50        9.33
# 542    yokadouma   3.52   15.05     71.35        95          99        1.45
# 543    roebourne -20.78  117.13     66.74        91          32        3.09
# 544       samfya -11.36   29.56     80.02        37          65        3.96
#
#     Country        Date
# 0        RU  1603821583
# 1        US  1603821558
# 2        CL  1603821586
# 3        GL  1603821587
# 4        ZA  1603821588
# ..      ...         ...
# 540      CD  1603822280
# 541      KE  1603822281
# 542      CM  1603822282
# 543      AU  1603822284
# 544      ZM  1603822285
#
# [545 rows x 9 columns]

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv
clean_city_data.to_csv('..\output_data\cities.csv', index=True)

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Max Temperature ({today})')
plt.grid()

# Save the figure
plt.savefig('../output_data/Fig1.png')

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Humidity ({today})')
plt.grid()

# Save the figure
plt.savefig('../output_data/Fig2.png')

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Cloudiness ({today})')
plt.grid()

# Save the figure
plt.savefig('../output_data/Fig3.png')

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Wind Speed ({today})')
plt.grid()

# Save the figure
plt.savefig('../output_data/Fig4.png')

# Show plot
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
# Create a function to create Linear Regression plots
def line_regression(x_values, y_values):
    slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
    Y_pred = slope*x_values + intercept # make predictions
    return Y_pred, r_value

# %%
# Create Northern and Southern Hemisphere DataFrames
North_cities_weather_df = cities_weather_df.loc[cities_weather_df['Lat'] > 0]
South_cities_weather_df = cities_weather_df.loc[cities_weather_df['Lat'] < 0]

# %% [markdown]
# ### Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Max Temp']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept # make predictions

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (1,1),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig5.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: -0.8800636477751821

# %%
# Linear regression on Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Max Temp']
plt.scatter(x_values,y_values)
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept # make predictions

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-25,40),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig6.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.7099355624370003

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Humidity']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (40,10),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Humidity')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig7.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.3362500041878784

# %%
# Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Humidity']
plt.scatter(x_values,y_values)
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept # make predictions

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-50,20),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Humidity')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig8.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.07771732883349165

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Cloudiness']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (40,10),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig9.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.12223498673624618

# %%
# Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Cloudiness']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-30,30),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig10.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.29161126424814265

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Wind Speed']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (40,25),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig11.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.17375305285924117

# %%
# Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Wind Speed']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-50,20),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig12.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: -0.20310873372467425
