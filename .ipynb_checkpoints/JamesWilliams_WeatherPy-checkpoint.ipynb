# %% [markdown]
# ## WeatherPy

# %% [markdown]
# **Note**
#
# - Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os

# Import API key
from JamesWilliams_api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
#
# - Perform a weather check on each city using a series of successive API calls.
# - Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Print to logger
print(f'\nBeginning Data Retrieval\n\
-----------------------------\n')

# Create counters
record = 0
sets = 1
cities_weather = []

# Loop through all the cities in our list
for city in cities:
    
    record += 1
    print(f'Processing Record {record} of Set {sets} | {city}')
    
     # Group cities in sets of 50 for logging purposes
    if(record == 50):
        record = 0
        sets += 1
        
    # URL for Weather Map API Call    
    url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&q={city}&APPID={weather_api_key}" 
    
    time.sleep(1)
    response = requests.get(url).json()
    # try and and except to add info to lists
    try:
        cities_weather.append({
            'City': city,
            'Lat': response['coord']['lat'],
            'Lon': response['coord']['lon'],
            'Max Temp': response['main']['temp_max'],
            'Humidity': response['main']['humidity'],
            'Cloudiness': response['clouds']['all'],
            'Wind Speed': response['wind']['speed'],
            'Country': response['sys']['country'],
            'Date': response['dt'],
            })
    except:
        print('City not found. Skipping...')
print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# #print completed results
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | abha
# Processing Record 2 of Set 1 | lac du bonnet
# Processing Record 3 of Set 1 | san rafael
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | mackay
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | dinar
# Processing Record 12 of Set 1 | san patricio
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | harnosand
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | leningradskiy
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | benavente
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | gizo
# Processing Record 28 of Set 1 | razole
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | lamar
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | cairns
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | tomatlan
# Processing Record 37 of Set 1 | tursunzoda
# Processing Record 38 of Set 1 | arauca
# Processing Record 39 of Set 1 | san juan de colon
# Processing Record 40 of Set 1 | pringsewu
# Processing Record 41 of Set 1 | phnum penh
# City not found. Skipping...
# Processing Record 42 of Set 1 | tynda
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | skibbereen
# Processing Record 45 of Set 1 | jinchang
# Processing Record 46 of Set 1 | katangli
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | san cristobal
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | gari
# Processing Record 6 of Set 2 | northam
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | yarmouth
# Processing Record 11 of Set 2 | portland
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | westport
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | ngunguru
# Processing Record 16 of Set 2 | peace river
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | hanzhong
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | port hedland
# Processing Record 24 of Set 2 | port said
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | pedasi
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | riberalta
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | san carlos de bariloche
# Processing Record 33 of Set 2 | mangrol
# Processing Record 34 of Set 2 | plettenberg bay
# Processing Record 35 of Set 2 | labuhan
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | springbok
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | yarada
# Processing Record 40 of Set 2 | victoria point
# Processing Record 41 of Set 2 | lavrentiya
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | moche
# Processing Record 44 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 2 | bucerias
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | porto novo
# Processing Record 49 of Set 2 | pecos
# Processing Record 50 of Set 2 | ushuaia
# Processing Record 1 of Set 3 | aguimes
# Processing Record 2 of Set 3 | mawlaik
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | zaoyang
# Processing Record 5 of Set 3 | tiarei
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | dholka
# Processing Record 8 of Set 3 | karpathos
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | khromtau
# Processing Record 11 of Set 3 | haines junction
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | aasiaat
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | gravdal
# Processing Record 16 of Set 3 | koumac
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | acapulco
# Processing Record 19 of Set 3 | palmas
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | olavarria
# Processing Record 22 of Set 3 | coromandel
# Processing Record 23 of Set 3 | araceli
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | ceska kamenice
# Processing Record 29 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 3 | lumphat
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | tarakan
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | sinnamary
# Processing Record 37 of Set 3 | stromness
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | juneau
# Processing Record 40 of Set 3 | severo-kurilsk
# Processing Record 41 of Set 3 | hopkinsville
# Processing Record 42 of Set 3 | airai
# Processing Record 43 of Set 3 | chumikan
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | turkistan
# Processing Record 46 of Set 3 | tulun
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | kasempa
# Processing Record 49 of Set 3 | tshela
# Processing Record 50 of Set 3 | alofi
# Processing Record 1 of Set 4 | merritt island
# Processing Record 2 of Set 4 | hamilton
# Processing Record 3 of Set 4 | pisco
# Processing Record 4 of Set 4 | coahuayana
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | karamken
# City not found. Skipping...
# Processing Record 8 of Set 4 | hami
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | darhan
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | manado
# Processing Record 14 of Set 4 | komsomolskiy
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | emba
# Processing Record 17 of Set 4 | angamali
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | naze
# Processing Record 20 of Set 4 | garm
# City not found. Skipping...
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | meulaboh
# Processing Record 23 of Set 4 | lago da pedra
# Processing Record 24 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 4 | shimoda
# Processing Record 26 of Set 4 | dubai
# Processing Record 27 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 4 | hambantota
# Processing Record 29 of Set 4 | tigil
# Processing Record 30 of Set 4 | taoudenni
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | rio gallegos
# Processing Record 33 of Set 4 | tombouctou
# Processing Record 34 of Set 4 | talaya
# Processing Record 35 of Set 4 | manzil tamim
# City not found. Skipping...
# Processing Record 36 of Set 4 | lodja
# Processing Record 37 of Set 4 | katav-ivanovsk
# Processing Record 38 of Set 4 | caravelas
# Processing Record 39 of Set 4 | sao francisco
# Processing Record 40 of Set 4 | almeirim
# Processing Record 41 of Set 4 | aleksandrov gay
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | soma
# Processing Record 44 of Set 4 | ilulissat
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | hobyo
# Processing Record 48 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 4 | katobu
# Processing Record 50 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 5 | suntar
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | jak
# Processing Record 4 of Set 5 | sapa
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | yuli
# Processing Record 7 of Set 5 | almenara
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | amapa
# Processing Record 11 of Set 5 | hollins
# Processing Record 12 of Set 5 | nalut
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | vung tau
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | coffs harbour
# Processing Record 17 of Set 5 | nara
# Processing Record 18 of Set 5 | kadnikov
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | vestmanna
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | buin
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | carnarvon
# Processing Record 25 of Set 5 | asosa
# Processing Record 26 of Set 5 | miechow
# Processing Record 27 of Set 5 | galesong
# Processing Record 28 of Set 5 | mahebourg
# Processing Record 29 of Set 5 | matara
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | badvel
# Processing Record 34 of Set 5 | andenes
# Processing Record 35 of Set 5 | balikpapan
# Processing Record 36 of Set 5 | joao pinheiro
# Processing Record 37 of Set 5 | berezovyy
# Processing Record 38 of Set 5 | kloulklubed
# Processing Record 39 of Set 5 | faya
# Processing Record 40 of Set 5 | khatanga
# Processing Record 41 of Set 5 | tabulbah
# City not found. Skipping...
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | takestan
# Processing Record 44 of Set 5 | chupa
# Processing Record 45 of Set 5 | lamu
# Processing Record 46 of Set 5 | jalpan
# Processing Record 47 of Set 5 | sao jose da coroa grande
# Processing Record 48 of Set 5 | saquena
# Processing Record 49 of Set 5 | beidao
# Processing Record 50 of Set 5 | dondukovskaya
# Processing Record 1 of Set 6 | burns lake
# Processing Record 2 of Set 6 | xochistlahuaca
# Processing Record 3 of Set 6 | belmonte
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | zhezkazgan
# Processing Record 6 of Set 6 | teacapan
# Processing Record 7 of Set 6 | dharchula
# Processing Record 8 of Set 6 | gao
# Processing Record 9 of Set 6 | loyola
# Processing Record 10 of Set 6 | marathon
# Processing Record 11 of Set 6 | auki
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | puerto narino
# Processing Record 14 of Set 6 | mojo
# Processing Record 15 of Set 6 | bakchar
# Processing Record 16 of Set 6 | puerto escondido
# Processing Record 17 of Set 6 | marzuq
# Processing Record 18 of Set 6 | pacific grove
# Processing Record 19 of Set 6 | flinders
# Processing Record 20 of Set 6 | la paz
# Processing Record 21 of Set 6 | olafsvik
# Processing Record 22 of Set 6 | senador jose porfirio
# Processing Record 23 of Set 6 | noumea
# Processing Record 24 of Set 6 | kahului
# Processing Record 25 of Set 6 | samana
# Processing Record 26 of Set 6 | atambua
# Processing Record 27 of Set 6 | seymchan
# Processing Record 28 of Set 6 | lulea
# Processing Record 29 of Set 6 | karpogory
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | ulundi
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | makakilo city
# Processing Record 34 of Set 6 | svidnik
# Processing Record 35 of Set 6 | carutapera
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | gat
# Processing Record 38 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 6 | pailon
# Processing Record 40 of Set 6 | rabo de peixe
# Processing Record 41 of Set 6 | sapele
# Processing Record 42 of Set 6 | cervo
# Processing Record 43 of Set 6 | kirakira
# Processing Record 44 of Set 6 | aksarayskiy
# Processing Record 45 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 6 | dapitan
# Processing Record 47 of Set 6 | kutum
# Processing Record 48 of Set 6 | udachnyy
# Processing Record 49 of Set 6 | sakakah
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | ronne
# Processing Record 2 of Set 7 | dimapur
# Processing Record 3 of Set 7 | dombarovskiy
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | broken hill
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | yuzhno-kurilsk
# Processing Record 8 of Set 7 | saint george
# Processing Record 9 of Set 7 | la asuncion
# Processing Record 10 of Set 7 | seka
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 13 of Set 7 | bukama
# Processing Record 14 of Set 7 | superior
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | maceio
# Processing Record 17 of Set 7 | yulara
# Processing Record 18 of Set 7 | grand gaube
# Processing Record 19 of Set 7 | kidal
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | capaci
# Processing Record 22 of Set 7 | bardstown
# Processing Record 23 of Set 7 | halifax
# Processing Record 24 of Set 7 | samarai
# Processing Record 25 of Set 7 | ruteng
# Processing Record 26 of Set 7 | goderich
# Processing Record 27 of Set 7 | necochea
# Processing Record 28 of Set 7 | maneromango
# Processing Record 29 of Set 7 | malinovskiy
# Processing Record 30 of Set 7 | araouane
# Processing Record 31 of Set 7 | sobolevo
# Processing Record 32 of Set 7 | los llanos de aridane
# Processing Record 33 of Set 7 | anju
# Processing Record 34 of Set 7 | doka
# Processing Record 35 of Set 7 | obala
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | banda aceh
# Processing Record 39 of Set 7 | mecca
# Processing Record 40 of Set 7 | umm kaddadah
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | dunedin
# Processing Record 44 of Set 7 | kaniama
# Processing Record 45 of Set 7 | milkovo
# Processing Record 46 of Set 7 | pelotas
# Processing Record 47 of Set 7 | sola
# Processing Record 48 of Set 7 | kogon
# Processing Record 49 of Set 7 | bandarbeyla
# Processing Record 50 of Set 7 | bilibino
# Processing Record 1 of Set 8 | edd
# Processing Record 2 of Set 8 | avanigadda
# Processing Record 3 of Set 8 | terrell
# Processing Record 4 of Set 8 | dabat
# Processing Record 5 of Set 8 | carberry
# Processing Record 6 of Set 8 | yar-sale
# Processing Record 7 of Set 8 | inzhavino
# Processing Record 8 of Set 8 | muroto
# Processing Record 9 of Set 8 | tutoia
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | luganville
# Processing Record 12 of Set 8 | half moon bay
# Processing Record 13 of Set 8 | saskylakh
# Processing Record 14 of Set 8 | biltine
# Processing Record 15 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 8 | karatau
# Processing Record 17 of Set 8 | matane
# Processing Record 18 of Set 8 | muros
# Processing Record 19 of Set 8 | nioro
# Processing Record 20 of Set 8 | dukat
# Processing Record 21 of Set 8 | tasiilaq
# Processing Record 22 of Set 8 | weinan
# Processing Record 23 of Set 8 | cuenca
# Processing Record 24 of Set 8 | santa rosa
# Processing Record 25 of Set 8 | monte santo de minas
# Processing Record 26 of Set 8 | quatre cocos
# Processing Record 27 of Set 8 | iqaluit
# Processing Record 28 of Set 8 | verkhnevilyuysk
# Processing Record 29 of Set 8 | baturaja
# Processing Record 30 of Set 8 | faanui
# Processing Record 31 of Set 8 | sherkot
# Processing Record 32 of Set 8 | high level
# Processing Record 33 of Set 8 | pathein
# Processing Record 34 of Set 8 | monte santo
# Processing Record 35 of Set 8 | puerto del rosario
# Processing Record 36 of Set 8 | methoni
# Processing Record 37 of Set 8 | mogadishu
# Processing Record 38 of Set 8 | azare
# Processing Record 39 of Set 8 | castelo branco
# Processing Record 40 of Set 8 | honningsvag
# Processing Record 41 of Set 8 | krasnoselkup
# Processing Record 42 of Set 8 | beruni
# City not found. Skipping...
# Processing Record 43 of Set 8 | ariguani
# Processing Record 44 of Set 8 | bengkulu
# Processing Record 45 of Set 8 | nouadhibou
# Processing Record 46 of Set 8 | ulverstone
# Processing Record 47 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 8 | katsuura
# Processing Record 49 of Set 8 | honiara
# Processing Record 50 of Set 8 | omboue
# Processing Record 1 of Set 9 | lusambo
# Processing Record 2 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | grindavik
# Processing Record 4 of Set 9 | dongying
# Processing Record 5 of Set 9 | saldanha
# Processing Record 6 of Set 9 | cayenne
# Processing Record 7 of Set 9 | tongchuan
# Processing Record 8 of Set 9 | burica
# City not found. Skipping...
# Processing Record 9 of Set 9 | piacabucu
# Processing Record 10 of Set 9 | waitati
# Processing Record 11 of Set 9 | berlevag
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | hervey bay
# Processing Record 14 of Set 9 | deneysville
# Processing Record 15 of Set 9 | padang
# Processing Record 16 of Set 9 | okha
# Processing Record 17 of Set 9 | dandong
# Processing Record 18 of Set 9 | hit
# Processing Record 19 of Set 9 | lagos
# Processing Record 20 of Set 9 | dormidontovka
# Processing Record 21 of Set 9 | syumsi
# Processing Record 22 of Set 9 | alpena
# Processing Record 23 of Set 9 | avera
# Processing Record 24 of Set 9 | gallup
# Processing Record 25 of Set 9 | kolda
# Processing Record 26 of Set 9 | kattivakkam
# Processing Record 27 of Set 9 | indergarh
# Processing Record 28 of Set 9 | leh
# Processing Record 29 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 9 | criscior
# Processing Record 31 of Set 9 | lagunas
# Processing Record 32 of Set 9 | kem
# Processing Record 33 of Set 9 | iskateley
# Processing Record 34 of Set 9 | karratha
# Processing Record 35 of Set 9 | geldermalsen
# Processing Record 36 of Set 9 | yuanping
# Processing Record 37 of Set 9 | general roca
# Processing Record 38 of Set 9 | limon
# Processing Record 39 of Set 9 | nemuro
# Processing Record 40 of Set 9 | nantucket
# Processing Record 41 of Set 9 | mehamn
# Processing Record 42 of Set 9 | scarborough
# Processing Record 43 of Set 9 | yumen
# Processing Record 44 of Set 9 | charters towers
# Processing Record 45 of Set 9 | diu
# Processing Record 46 of Set 9 | najran
# Processing Record 47 of Set 9 | palana
# Processing Record 48 of Set 9 | tupancireta
# Processing Record 49 of Set 9 | pionerskiy
# Processing Record 50 of Set 9 | tres arroyos
# Processing Record 1 of Set 10 | sisimiut
# Processing Record 2 of Set 10 | bulgan
# Processing Record 3 of Set 10 | viedma
# Processing Record 4 of Set 10 | deputatskiy
# Processing Record 5 of Set 10 | laguna
# Processing Record 6 of Set 10 | ciudad bolivar
# Processing Record 7 of Set 10 | hakkari
# Processing Record 8 of Set 10 | mayo
# Processing Record 9 of Set 10 | worthington
# Processing Record 10 of Set 10 | filingue
# Processing Record 11 of Set 10 | desaguadero
# Processing Record 12 of Set 10 | abalak
# Processing Record 13 of Set 10 | kandrian
# Processing Record 14 of Set 10 | uyuni
# Processing Record 15 of Set 10 | dawlatabad
# Processing Record 16 of Set 10 | tabora
# Processing Record 17 of Set 10 | palmer
# Processing Record 18 of Set 10 | sharan
# Processing Record 19 of Set 10 | lorengau
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | buchanan
# Processing Record 22 of Set 10 | gashua
# Processing Record 23 of Set 10 | swellendam
# Processing Record 24 of Set 10 | salalah
# Processing Record 25 of Set 10 | bentiu
# Processing Record 26 of Set 10 | lerici
# Processing Record 27 of Set 10 | montepuez
# Processing Record 28 of Set 10 | portales
# Processing Record 29 of Set 10 | kibaya
# Processing Record 30 of Set 10 | kut chap
# Processing Record 31 of Set 10 | pangnirtung
# Processing Record 32 of Set 10 | prince rupert
# Processing Record 33 of Set 10 | constitucion
# Processing Record 34 of Set 10 | ambon
# Processing Record 35 of Set 10 | pangody
# Processing Record 36 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 10 | port hardy
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | stephenville
# Processing Record 40 of Set 10 | benicia
# Processing Record 41 of Set 10 | oda
# Processing Record 42 of Set 10 | manicore
# Processing Record 43 of Set 10 | eydhafushi
# Processing Record 44 of Set 10 | nanortalik
# Processing Record 45 of Set 10 | umea
# Processing Record 46 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 10 | nhulunbuy
# Processing Record 49 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 10 | lincoln
# Processing Record 1 of Set 11 | orgun
# City not found. Skipping...
# Processing Record 2 of Set 11 | yenagoa
# Processing Record 3 of Set 11 | ambilobe
# Processing Record 4 of Set 11 | natal
# Processing Record 5 of Set 11 | caracollo
# Processing Record 6 of Set 11 | bilma
# Processing Record 7 of Set 11 | amarante do maranhao
# Processing Record 8 of Set 11 | williamsport
# Processing Record 9 of Set 11 | novopavlovsk
# Processing Record 10 of Set 11 | harper
# Processing Record 11 of Set 11 | rehoboth
# Processing Record 12 of Set 11 | port macquarie
# Processing Record 13 of Set 11 | oksfjord
# Processing Record 14 of Set 11 | osoyoos
# Processing Record 15 of Set 11 | gannan
# Processing Record 16 of Set 11 | tyret pervaya
# Processing Record 17 of Set 11 | aksarka
# Processing Record 18 of Set 11 | morococha
# Processing Record 19 of Set 11 | shache
# Processing Record 20 of Set 11 | tautira
# Processing Record 21 of Set 11 | svetlaya
# Processing Record 22 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 11 | booue
# Processing Record 24 of Set 11 | tucurui
# Processing Record 25 of Set 11 | atar
# Processing Record 26 of Set 11 | khem karan
# Processing Record 27 of Set 11 | zyryanka
# Processing Record 28 of Set 11 | kashi
# Processing Record 29 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 30 of Set 11 | pemba
# Processing Record 31 of Set 11 | novyy urengoy
# Processing Record 32 of Set 11 | crossville
# Processing Record 33 of Set 11 | panzhihua
# Processing Record 34 of Set 11 | banjar
# Processing Record 35 of Set 11 | pareora
# Processing Record 36 of Set 11 | goshogawara
# Processing Record 37 of Set 11 | ekhabi
# Processing Record 38 of Set 11 | biu
# Processing Record 39 of Set 11 | atka
# City not found. Skipping...
# Processing Record 40 of Set 11 | alekseyevskaya
# Processing Record 41 of Set 11 | bama
# Processing Record 42 of Set 11 | taree
# Processing Record 43 of Set 11 | sioux lookout
# Processing Record 44 of Set 11 | warrington
# Processing Record 45 of Set 11 | bozoum
# Processing Record 46 of Set 11 | nyurba
# Processing Record 47 of Set 11 | mahibadhoo
# Processing Record 48 of Set 11 | bara
# Processing Record 49 of Set 11 | raga
# Processing Record 50 of Set 11 | eyl
# Processing Record 1 of Set 12 | hualmay
# Processing Record 2 of Set 12 | chicama
# Processing Record 3 of Set 12 | nagato
# Processing Record 4 of Set 12 | hovd
# Processing Record 5 of Set 12 | villa sandino
# Processing Record 6 of Set 12 | novopokrovka
# Processing Record 7 of Set 12 | tessalit
# Processing Record 8 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 12 | presidencia roque saenz pena
# Processing Record 10 of Set 12 | dobrovice
# Processing Record 11 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 12 | san ramon de la nueva oran
# Processing Record 13 of Set 12 | ishigaki
# Processing Record 14 of Set 12 | morondava
# Processing Record 15 of Set 12 | varzob
# Processing Record 16 of Set 12 | pyapon
# Processing Record 17 of Set 12 | kismayo
# Processing Record 18 of Set 12 | ewa beach
# Processing Record 19 of Set 12 | hammerfest
# Processing Record 20 of Set 12 | sete lagoas
# Processing Record 21 of Set 12 | colquechaca
# Processing Record 22 of Set 12 | iracoubo
# Processing Record 23 of Set 12 | seminole
# Processing Record 24 of Set 12 | toungoo
# City not found. Skipping...
# Processing Record 25 of Set 12 | beloha
# Processing Record 26 of Set 12 | khandyga
# Processing Record 27 of Set 12 | nepalganj
# City not found. Skipping...
# Processing Record 28 of Set 12 | artyom
# Processing Record 29 of Set 12 | kempsey
# Processing Record 30 of Set 12 | rudnogorsk
# Processing Record 31 of Set 12 | alta floresta
# Processing Record 32 of Set 12 | apatou
# Processing Record 33 of Set 12 | prikubanskiy
# Processing Record 34 of Set 12 | rosita
# Processing Record 35 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 12 | asau
# Processing Record 37 of Set 12 | zhigansk
# Processing Record 38 of Set 12 | santa ines
# Processing Record 39 of Set 12 | itarema
# Processing Record 40 of Set 12 | hofn
# Processing Record 41 of Set 12 | havre-saint-pierre
# Processing Record 42 of Set 12 | srednekolymsk
# Processing Record 43 of Set 12 | jiquipilas
# Processing Record 44 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 45 of Set 12 | gardan diwal
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# - Export the city data into a .csv.
# - Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
cities_weather_df = pd.DataFrame(cities_weather)
# Show Record Count
cities_weather_df.count()
# Out:
# City          548
# Lat           548
# Lon           548
# Max Temp      548
# Humidity      548
# Cloudiness    548
# Wind Speed    548
# Country       548
# Date          548
# dtype: int64

# %%
# Display the City Data Frame
cities_weather_df
# Out:
#                    City    Lat     Lon  Max Temp  Humidity  Cloudiness  \
# 0                  abha  18.22   42.51     59.00        35           0
# 1         lac du bonnet  50.25  -96.06     28.00        98          75
# 2            san rafael -34.62  -68.33     66.97        25           1
# 3             fairbanks  64.84 -147.72     19.00        78          90
# 4            nikolskoye  59.70   30.79     50.00        93          90
# ..                  ...    ...     ...       ...       ...         ...
# 543             itarema  -2.92  -39.92     79.02        77           2
# 544                hofn  64.25  -15.21     46.00        80         100
# 545  havre-saint-pierre  50.23  -63.60     30.54        87          62
# 546       srednekolymsk  67.45  153.68      3.15        94         100
# 547          jiquipilas  16.67  -93.65     80.60        69          90
#
#      Wind Speed Country        Date
# 0          2.39      SA  1604009482
# 1          5.99      CA  1604009483
# 2         13.96      AR  1604009484
# 3          0.36      US  1604009373
# 4          4.47      RU  1604009487
# ..          ...     ...         ...
# 543       16.46      BR  1604010163
# 544       12.64      IS  1604010165
# 545       17.67      CA  1604010166
# 546        0.98      RU  1604010167
# 547       10.29      MX  1604010168
#
# [548 rows x 9 columns]

# %% [markdown]
# ### Inspect the data and remove the cities where the humidity > 100%.
#
# - Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_outliers = cities_weather_df.loc[cities_weather_df['Humidity'] > 100]
humidity_outliers
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lon, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indices = cities_weather_df.index[cities_weather_df['Humidity']>100].tolist()
indices
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = cities_weather_df.drop(indices, inplace=False)
clean_city_data
# Out:
#                    City    Lat     Lon  Max Temp  Humidity  Cloudiness  \
# 0                  abha  18.22   42.51     59.00        35           0
# 1         lac du bonnet  50.25  -96.06     28.00        98          75
# 2            san rafael -34.62  -68.33     66.97        25           1
# 3             fairbanks  64.84 -147.72     19.00        78          90
# 4            nikolskoye  59.70   30.79     50.00        93          90
# ..                  ...    ...     ...       ...       ...         ...
# 543             itarema  -2.92  -39.92     79.02        77           2
# 544                hofn  64.25  -15.21     46.00        80         100
# 545  havre-saint-pierre  50.23  -63.60     30.54        87          62
# 546       srednekolymsk  67.45  153.68      3.15        94         100
# 547          jiquipilas  16.67  -93.65     80.60        69          90
#
#      Wind Speed Country        Date
# 0          2.39      SA  1604009482
# 1          5.99      CA  1604009483
# 2         13.96      AR  1604009484
# 3          0.36      US  1604009373
# 4          4.47      RU  1604009487
# ..          ...     ...         ...
# 543       16.46      BR  1604010163
# 544       12.64      IS  1604010165
# 545       17.67      CA  1604010166
# 546        0.98      RU  1604010167
# 547       10.29      MX  1604010168
#
# [548 rows x 9 columns]

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv
clean_city_data.to_csv('cities.csv', index=True, header=True)

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Max Temperature ({today})')
plt.grid()

# Save the figure
plt.savefig('output_data/Fig1.png')

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Humidity ({today})')
plt.grid()

# Save the figure
plt.savefig('output_data/Fig2.png')

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Cloudiness ({today})')
plt.grid()

# Save the figure
plt.savefig('output_data/Fig3.png')

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_values = cities_weather_df['Lat']
y_values = cities_weather_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='k')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
today = pd.to_datetime("today")
plt.title(f'City Latitude vs. Wind Speed ({today})')
plt.grid()

# Save the figure
plt.savefig('output_data/Fig4.png')

# Show plot
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
# Create a function to create Linear Regression plots
def line_regression(x_values, y_values):
    slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
    Y_pred = slope*x_values + intercept # make predictions
    return Y_pred, r_value

# %%
# Create Northern and Southern Hemisphere DataFrames
North_cities_weather_df = cities_weather_df.loc[cities_weather_df['Lat'] > 0]
South_cities_weather_df = cities_weather_df.loc[cities_weather_df['Lat'] < 0]

# %% [markdown]
# ### Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Max Temp']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept # make predictions

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (1,1),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('output_data/Fig5.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: -0.8717000152320481

# %%
# Linear regression on Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Max Temp']
plt.scatter(x_values,y_values)
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept # make predictions

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-25,40),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig6.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.7099355624370003

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Humidity']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (40,10),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Humidity')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('output_data/Fig7.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.34982579780158574

# %%
# Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Humidity']
plt.scatter(x_values,y_values)
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept # make predictions

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-50,20),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Humidity')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig8.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.07771732883349165

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Cloudiness']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (40,10),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('output_data/Fig9.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.16398015656582754

# %%
# Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Cloudiness']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-30,30),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('../output_data/Fig10.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.29161126424814265

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = North_cities_weather_df['Lat']
y_values = North_cities_weather_df['Wind Speed']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (40,25),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('output_data/Fig11.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: 0.12354625130445707

# %%
# Southern Hemisphere
x_values = South_cities_weather_df['Lat']
y_values = South_cities_weather_df['Wind Speed']
plt.scatter(x_values,y_values)

slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
Y_pred = slope*x_values + intercept

plt.plot(x_values, Y_pred, color='r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq, (-50,20),fontsize=15,color="red")
              
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
today = pd.to_datetime("today")


# Save the figure
plt.savefig('output_data/Fig12.png')

# Show plot and r value
print(f'The r_value is: {r_value}')
plt.show()
# Out:
# The r_value is: -0.2550202218663272
